# %%
# data augmentation
# model searching, place classficiation
# data analysis

# %%
from pickletools import optimize
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import transforms
import custom_dataset
import augmentation

# %%
data_dir = "../landmark_classification/dataset/"
transform = transforms.Compose([
    transforms.ToTensor()
])


dataset = custom_dataset.Dataset(os.path.join(data_dir, 'train'), transform=transform)

# %%
images = dataset.images
categorized_images = []
for i in range(10):
    categorized_images.append(dataset.categorized_images(i, os.path.join(data_dir, 'train.csv')))

# %%
def show_images(images, images_per_row=5):
    n_images = len(images)
    n_rows = ((n_images-1) // images_per_row) + 1
    plt.figure(figsize=(20,50))
    for i in range(n_images):
        plt.subplot(n_rows, images_per_row, i+1)
        plt.subplots_adjust(hspace=None, wspace=None)
        plt.imshow(images[i].permute(1, 2, 0))
        plt.axis('off')
    plt.show()

# %%
len(dataset)
# Out:
# 723

# %%
brighteness = dataset.brighteness(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\rlawo\Desktop\Dacon\landmark_classification\image_visualization.ipynb 셀 7 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rlawo/Desktop/Dacon/landmark_classification/image_visualization.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> brighteness = dataset.brighteness(0.5)
#
# File c:\Users\rlawo\Desktop\Dacon\landmark_classification\custom_dataset.py:64, in Dataset.brighteness(self, unit, maximum, minimum)
#      62 for image in self.images:
#      63     for degree in range(int(minimum//unit), int(maximum//unit)+1):
# ---> 64         modified_images.append(functional.adjust_brightness(image, unit*degree))
#      65 print(f'{len(modified_images)} images generated.')
#      66 return modified_images
#
# ...

# %%
image = brighteness(images[0], 0.5)
plt.imshow(image.permute(1, 2, 0))

# %%
2//0.5
# Out:
# 4.0
